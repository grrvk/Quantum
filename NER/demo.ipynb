# %% [markdown]
# # NER Model Training and Inference Demo
#
# Notebook demonstrates how to train a BERT-based Named Entity Recognition model and use it for inference on new text.
#
# ## Overview
#
# The NER system recognizes **MOUNTAIN** entities in text using:
# - **Model**: DistilBERT
# - **Task**: Token classification with BIO tagging
# - **Evaluation**: Precision, Recall, F1 Score

# %% [markdown]
# ## Setup and Installation

# %%
# Install required packages
# %cd NER
# !pip install -r requirements.txt

import warnings
warnings.filterwarnings('ignore')
# Out:
# [Errno 2] No such file or directory: 'NER'
# /Users/vika/PycharmProjects/Quantum/NER
# Requirement already satisfied: plotly~=6.3.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (6.3.1)
# Requirement already satisfied: numpy~=2.3.4 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.3.4)
# Requirement already satisfied: pandas~=2.3.3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: transformers~=4.57.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (4.57.1)
# Requirement already satisfied: datasets~=4.3.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: seqeval~=1.2.2 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: torch~=2.9.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.9.0)
# Requirement already satisfied: ollama~=0.6.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.6.0)
# Requirement already satisfied: pydantic~=2.12.3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (2.12.3)
# Requirement already satisfied: tqdm~=4.67.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (4.67.1)
# Requirement already satisfied: matplotlib~=3.10.7 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (3.10.7)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from plotly~=6.3.1->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: packaging in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from plotly~=6.3.1->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from pandas~=2.3.3->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from pandas~=2.3.3->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from pandas~=2.3.3->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: filelock in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (2025.10.23)
# Requirement already satisfied: requests in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from transformers~=4.57.1->-r requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from datasets~=4.3.0->-r requirements.txt (line 5)) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from datasets~=4.3.0->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from datasets~=4.3.0->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: xxhash in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from datasets~=4.3.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from datasets~=4.3.0->-r requirements.txt (line 5)) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2025.9.0,>=2023.1.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from datasets~=4.3.0->-r requirements.txt (line 5)) (2025.9.0)
# Requirement already satisfied: scikit-learn>=0.21.3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from seqeval~=1.2.2->-r requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from torch~=2.9.0->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from torch~=2.9.0->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from torch~=2.9.0->-r requirements.txt (line 7)) (3.5)
# Requirement already satisfied: jinja2 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from torch~=2.9.0->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from pydantic~=2.12.3->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from pydantic~=2.12.3->-r requirements.txt (line 9)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from pydantic~=2.12.3->-r requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from matplotlib~=3.10.7->-r requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from matplotlib~=3.10.7->-r requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from matplotlib~=3.10.7->-r requirements.txt (line 11)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from matplotlib~=3.10.7->-r requirements.txt (line 11)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from matplotlib~=3.10.7->-r requirements.txt (line 11)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from matplotlib~=3.10.7->-r requirements.txt (line 11)) (3.2.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (3.13.1)
# Requirement already satisfied: anyio in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets~=4.3.0->-r requirements.txt (line 5)) (4.11.0)
# Requirement already satisfied: certifi in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets~=4.3.0->-r requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets~=4.3.0->-r requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from httpx<1.0.0->datasets~=4.3.0->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets~=4.3.0->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers~=4.57.1->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas~=2.3.3->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from requests->transformers~=4.57.1->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from requests->transformers~=4.57.1->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: scipy>=1.8.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval~=1.2.2->-r requirements.txt (line 6)) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval~=1.2.2->-r requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from scikit-learn>=0.21.3->seqeval~=1.2.2->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch~=2.9.0->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from jinja2->torch~=2.9.0->-r requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets~=4.3.0->-r requirements.txt (line 5)) (1.22.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/vika/PycharmProjects/Quantum/.venv/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets~=4.3.0->-r requirements.txt (line 5)) (1.3.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Part 1: Model Training
#
# Train a BERT-based NER model on the mountain dataset.

# %%
# Initialize the trainer
from NER.src.model.ner_train import NERTrainer

trainer = NERTrainer(model_name="distilbert-base-uncased")

# Load training data
print("Loading training data...")
train_data = trainer.load_data_from_csv('results/data/train_dataset.csv')
print(f"Loaded {len(train_data['tokens'])} samples")
# Out:
# Loading training data...
#
# Loaded 3000 samples

# %%
# Train the model
from NER.src.model.ner_inference import NERInference

print("Starting training...")

trained_trainer = trainer.train(
    training_data=train_data,
    output_dir="results/ner-model",
    num_train_epochs=3,
    per_device_train_batch_size=64,
    per_device_eval_batch_size=64,
    learning_rate=2e-5,
    weight_decay=0.01,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1"
)
# Out:
# Starting training...
# Training samples: 2400
# Validation samples: 600
# Map:   0%|          | 0/2400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Starting training...
#     <div>
#
#       <progress value='114' max='114' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [114/114 00:40, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.096089</td>
#       <td>0.714286</td>
#       <td>0.816667</td>
#       <td>0.762053</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.037464</td>
#       <td>0.927632</td>
#       <td>0.940000</td>
#       <td>0.933775</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.031527</td>
#       <td>0.931373</td>
#       <td>0.950000</td>
#       <td>0.940594</td>
#     </tr>
#   </tbody>
# </table><p>
# Model saved to results/ner-model

# %% [markdown]
# ### Visualize Training Metrics
#
# Plot the training metrics to see how the model performed:

# %%
NERTrainer.plot_training_metrics(trained_trainer, show_plot=True)

# %% [markdown]
# ## Part 2: Model Inference

# %%
# Initialize the inference pipeline
print("Loading trained model...")
ner_inference = NERInference(model_path="results/ner-model")
print("✓ Model loaded successfully!")
# Out:
# Device set to use cpu
# Loading trained model...
# ✓ Model loaded successfully!

# %% [markdown]
# ### Single Text Prediction
#
# Test the model on individual sentences:

# %%
test_texts = [
    "Mount Everest is the highest peak in the world.",
    "I climbed Kilimanjaro last year and it was amazing.",
    "The Matterhorn is a famous mountain in the Swiss Alps.",
    "Denali National Park features the tallest mountain in North America."
]

for text in test_texts:
    print(f"Text: {text}")
    entities = ner_inference.predict_single(text)
    if entities:
        for entity in entities:
            print(f"  Mountain: {entity['word']:20s} | Confidence: {entity['score']:.3f}")
    else:
        print("  No mountains detected")
    print("-"*50)
# Out:
# Text: Mount Everest is the highest peak in the world.
#   Mountain: mount everest        | Confidence: 0.962
# --------------------------------------------------
# Text: I climbed Kilimanjaro last year and it was amazing.
#   Mountain: kilimanjaro          | Confidence: 0.900
# --------------------------------------------------
# Text: The Matterhorn is a famous mountain in the Swiss Alps.
#   Mountain: matterhorn           | Confidence: 0.983
# --------------------------------------------------
# Text: Denali National Park features the tallest mountain in North America.
#   Mountain: denali               | Confidence: 0.965
# --------------------------------------------------

# %% [markdown]
# ### Prediction from prepared csv

# %%
import pandas as pd

df = pd.read_csv('results/data/inference_dataset.csv')
sample_texts = df['text'].tolist()

results_df = ner_inference.predict_to_dataframe(sample_texts)
print("Prediction Results:")
print(results_df.head())
# Out:
# Prediction Results:
#                                                 text             entity  \
# 0  The Matterhorn, a famous mountain with a disti...         matterhorn
# 1  Fuji, Japan's highest mountain, is an active s...               fuji
# 2  Aspiring Mountain, also known as Aspiring, is ...  aspiring mountain
# 3  Aspiring Mountain, also known as Aspiring, is ...           aspiring
# 4  Mount Whitney, at 14,505 feet, is the highest ...      mount whitney
#
#       label  confidence
# 0  MOUNTAIN    0.983667
# 1  MOUNTAIN    0.968383
# 2  MOUNTAIN    0.816696
# 3  MOUNTAIN    0.807276
# 4  MOUNTAIN    0.974698

# %% [markdown]
# ### Analyze Inference Results

# %%
predicted_results = results_df[results_df['entity'].notna()]

print("Inference Statistics:")
print(f"Total texts analyzed:       {len(results_df):,}")
print(f"Texts with entities found:  {len(predicted_results):,}")
print(f"Detection rate:             {len(predicted_results)/len(results_df)*100:.1f}%")

if len(predicted_results) > 0:
    print(f"\nAverage confidence:        {predicted_results['confidence'].mean():.3f}")
    print(f"Highest confidence:        {predicted_results['confidence'].max():.3f}")
    print(f"Lowest confidence:         {predicted_results['confidence'].min():.3f}")
# Out:
# Inference Statistics:
# Total texts analyzed:       210
# Texts with entities found:  204
# Detection rate:             97.1%
#
# Average confidence:        0.937
# Highest confidence:        0.984
# Lowest confidence:         0.450
